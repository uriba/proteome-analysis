# %%
#Initialization of basic data containers, gene annotation data, growth rates and cell volumes and selection of conditions to analyze.import csvfrom pandas.io.parsers import read_csvimport pandas as pdfrom scipy.stats import gaussian_kde,linregresspylab.rcParams['figure.figsize']=(8.0,6.0)#load uniprot to eco gene id mapping and convert it to a dictionary:unidict = {}uni_to_eco = read_csv('eco_uniprot_mapping.csv',sep='[\t:]',encoding='iso-8859-1',header = None, names = ['eco','bla','uniprot'])for i,row in uni_to_eco.iterrows():     unidict[row['uniprot']]=row['eco']    #load the eco annotation tree:annot_dict = {}with open('hierarchy_standardised.tms','rb') as annot_file:     annots = csv.reader(annot_file,delimiter='\t') #,encoding='iso-8859-1')     for row in annots:     	 if len(row) == 2:	    cat = row [-1]	 elif len(row) == 3:	    subcat = row[-1]	 elif len(row) == 4:	    component = row[-1]	 elif len(row) == 5:	    annot_dict[row[-1]]=(cat,subcat,component)	      # define the growth rates:gr = {    u'chemostat \u00b5=0.12': 0.12,     u'galactose':0.17,     u'chemostat \u00b5=0.20':0.2,     u'acetate':0.29,     u'chemostat \u00b5=0.35':0.35,    u'glucosamine':0.39,     u'pyruvate':0.4,     u'glycerol':0.47,    u'fumarate':0.47,     u'succinate':0.49,     u'chemostat \u00b5=0.5':0.5,     u'anaerobic' : 0.55,     u'glucose': 0.6,    u'LB':1.61    }gr = pd.Series(gr)# define cell volumes:volumes = {u'glucose': 3.2, u'anaerobic' : 2.9, u'chemostat \u00b5=0.12': 2.1, u'chemostat \u00b5=0.5':2.6, u'galactose':1.9, u'acetate':2.4, u'glycerol':2.3,     u'LB':4.4,     u'glucosamine':2.9, u'fumarate':2.4, u'succinate':2.4, u'pyruvate':2.1, u'chemostat \u00b5=0.20':2.2, u'chemostat \u00b5=0.35':2.4}volumes = pd.Series(volumes)# first load the data from the file.# As the file was exported from Excel, it uses Excel's encoding.ecoli_data = read_csv('coli_data.csv',header=1,encoding='iso-8859-1')#Split the data loaded into two sets - weight and count.idx = ecoli_data.columnsecoli_data_weight = ecoli_data[idx[0:10].append(idx[29:])]ecoli_data_count = ecoli_data[idx[0:29]]# Define the list of conditions that will be relevant for the analysis, (and the description column):cond_list = [    u'chemostat \u00b5=0.12',    u'galactose',    u'chemostat \u00b5=0.20',    u'acetate',    u'chemostat \u00b5=0.35',    u'glucosamine',    u'pyruvate',    u'glycerol',    u'fumarate',    u'succinate',    u'chemostat \u00b5=0.5',    u'anaerobic',    u'glucose',    u'LB']#Define the text fields that will be relevant for the analysis:desc_list = ['Description','UP_AC']# Refine the DataFrames to include only these conditions (and the protein descriptions):count_cond = desc_list+cond_listecoli_data_count = ecoli_data_count[count_cond]#duplicate headers are modified by read_csv and include a trailing '.1' string in their name.weight_cond = desc_list+[x+'.1' for x in cond_list] ecoli_data_weight = ecoli_data_weight[weight_cond]#rename the columns to remove the trailing '.1'ecoli_data_weight.columns = count_cond#select the relevant data for analysis out of the two options:ecoli_data = ecoli_data_weight#convert all columns, excluding 'Description', to floats, and 'Description' to string.ecoli_data_weight = ecoli_data_weight[ecoli_data_weight != 'below LOQ']ecoli_data_weight[cond_list] = ecoli_data_weight[cond_list].astype('float')ecoli_data_weight[desc_list] = ecoli_data_weight[desc_list].astype('string')ecoli_data = ecoli_data[ecoli_data != 'below LOQ']ecoli_data[cond_list] = ecoli_data[cond_list].astype('float')ecoli_data[desc_list] = ecoli_data[desc_list].astype('string')#Normalize to get concentrations (Use the total protein weight as the normalizing factor to avoid errors in cell volume measurements)ecoli_data[cond_list] = ecoli_data[cond_list] / ecoli_data_weight[cond_list].sum() #volumes[cond_list]#get the ribosomal proteins.ecoli_data_values = ecoli_data.drop(desc_list,1)ecoli_data_values = ecoli_data_values.dropna()ribs = ecoli_data['Description'].map(lambda x: 'ribosomal protein' in x)ribs_data = ecoli_data_values[ribs]ribs_avg = ribs_data.sum()gr = gr[ribs_avg.index]volumes = volumes[ribs_avg.index]

# %%
########################### Analysis of correlation of proteins to growth rate.xs = linspace(-1,1,100)covs = []catcovs = {}prots = {}high_cor_prots = {}threshold = 0.3hc_indices = []hc_prots = pd.DataFrame(columns = ecoli_data_values.columns)for row_index, row in ecoli_data_values.iterrows():    desc = []    # calculate the correlation and add it to the statistics    cov = row.cov(gr)/(row.std() * gr.std())    covs.append(cov)    # get the protein annotation information    eco = ecoli_data['UP_AC'][row_index]    uniprot = unidict[eco]    if uniprot in annot_dict:	desc = annot_dict[uniprot]	# set the counters of all the annotation fields that this protein belong to.	for i in range(0,3):	    if desc[i] not in prots:	       prots[desc[i]]=0	       high_cor_prots[desc[i]]=0	       catcovs[desc[i]]=[]	    prots[desc[i]]+=1	    catcovs[desc[i]].append(cov)	    if cov > threshold: # threshold for gr correlated protein		high_cor_prots[desc[i]]+=1    if cov > 0.5:# and cov < 0.8:       hc_indices.append(row_index)       hc_prots = hc_prots.append(row)prots_num = len(covs)density = gaussian_kde(covs)plot(xs,density(xs),label='All proteins')title('Estimated distributions of correlation with growth rate by functional group')print "number of proteins compared: %d" % prots_numprint "correlation by categories:"for i in set([x[0] for x in annot_dict.values()]):    if i in prots:	if i in high_cor_prots:	    print "%s : %d / %d" % (i,high_cor_prots[i],prots[i])	else:	    print "%s : %d / %d" % (i,0,prots[i])groups = ['Translation', 'Folding, Sorting and Degradation', 'Lipid Metabolism', 'Energy Metabolism', 'Membrane Transport', 'Amino Acid Metabolism', 'Not mapped']print "correlation by sub-categories:"for i in set([x[1] for x in annot_dict.values()]):    if i in prots:        if i in groups:	    density = gaussian_kde(catcovs[i])	    plot(xs,density(xs)*(float(prots[i])/prots_num),label=i)	if i in high_cor_prots:	    print "%s : %d / %d" % (i,high_cor_prots[i],prots[i])	else:	    print "%s : %d / %d" % (i,0,prots[i])legend(loc='upper left')savefig('some_subcategories_distributions.png')
# Out:
# number of proteins compared: 1981correlation by categories:Environmental Information Processing : 5 / 26Genetic Information Processing : 198 / 289Cellular Processes : 3 / 16Not mapped : 234 / 990Metabolism : 262 / 657correlation by sub-categories:Nucleotide Metabolism : 31 / 70Transcription : 14 / 44Metabolism of Other Amino Acids : 12 / 24Membrane Transport : 20 / 80Not mapped : 234 / 990Cell Motility : 0 / 5Other enzymes : 56 / 124Glycan Biosynthesis and Metabolism : 9 / 14Energy Metabolism : 14 / 37Signal Transduction : 5 / 26Metabolism of Cofactors and Vitamins : 33 / 65Cell Growth and Death : 1 / 3Translation : 99 / 109Lipid Metabolism : 17 / 34DNA maintenance : 32 / 49Xenobiotics Biodegradation and Metabolism : 2 / 4Metabolism of Terpenoids and Polyketides : 13 / 16Vesicular transport : 0 / 3Amino Acid Metabolism : 36 / 113Folding, Sorting and Degradation : 53 / 87Cytoskeleton : 2 / 5Carbohydrate Metabolism : 47 / 138

# %%
hist(covs,20)
# Out:
# (array([ 13,  49,  77,  85,  88,  93, 111, 128, 128, 125, 115, 116,  88,        71,  97,  82,  96, 116, 158, 145]), array([-0.89569667, -0.80155355, -0.70741043, -0.6132673 , -0.51912418,       -0.42498106, -0.33083794, -0.23669481, -0.14255169, -0.04840857,        0.04573455,  0.13987768,  0.2340208 ,  0.32816392,  0.42230705,        0.51645017,  0.61059329,  0.70473641,  0.79887954,  0.89302266,        0.98716578]), <a list of 20 Patch objects>)

# %%
# plot the correlation of growth rate to the sum of ribosomal proteinsplot(gr.values,ribs_avg.values,'.')

# %%
covs = []catcovs = {}prots = {}high_cor_prots = {}threshold = 0.3maxval = 5j = 0values = []group = 'Energy Metabolism'for row_index, row in ecoli_data_values.iterrows():    desc = []    # calculate the correlation    cov = row.cov(gr)/(row.std() * gr.std())    # get the protein annotation information    eco = ecoli_data['UP_AC'][row_index]    uniprot = unidict[eco]    if uniprot in annot_dict:	desc = annot_dict[uniprot]	if desc[1] == group and j < maxval:	    j += 1	    normvals = row/row.sum()	    values.append(normvals)	    covs.append(cov)for i in range(0,len(values)):    plot(gr.values,values[i],'-o',label="%f" % covs[i])legend(loc='upper left')title('five random %s proteins. Legend shows covariance' % group)ylim([0,0.2])xlim([0,gr.max()+0.1])savefig('Five%sProts.png' % group)

# %%
hc_weights = hc_prots / hc_prots.sum()

# %%
norm_vars = hc_weights.std(axis=1) / hc_weights.mean(axis=1)plot(hc_weights.mean(axis=1),norm_vars,'.')xscale('log')title('CV of intrinsic strength decreases when measured values are higher')xlabel('Intrinsic strength (log)')ylabel('CV of intrinsic strength')savefig('CVvsDetectionLevel.png')

# %%
high_weights = hc_weights[hc_weights.mean(axis=1)>0.0001]high_prots = hc_prots[hc_weights.mean(axis=1)>0.0001]norm_vars = high_weights.std(axis=1) / high_weights.mean(axis=1)#plot(high_weights.mean(axis=1),norm_vars,'.')#xscale('log')

# %%
plot(high_prots.std(axis=1)/high_prots.mean(axis=1),norm_vars,'.')plot(high_prots.std(axis=1)/high_prots.mean(axis=1),high_prots.std(axis=1)/high_prots.mean(axis=1),label='y=x')plot(high_prots.std(axis=1)/high_prots.mean(axis=1),high_prots.std(axis=1)/high_prots.mean(axis=1)-0.183,label='y=x-CV(cluster)')title('Intrinsic strengths predict measured values')xlabel('CV of protein concentration across conditions')ylabel('CV of intrinsic strength across conditions')xlim(0,1.3)ylim(0,1.3)legend()savefig('IntStrengthCVvsRawCV.png')

# %%
print gr.std()/gr.mean()print high_prots.sum().std()/high_prots.sum().mean()
# Out:
# 0.7585871709950.27215700818

# %%
plot(gr,high_prots.sum(),'.')plot(gr,gr*0.5)xlim(0,gr.max()+0.1)ylim(0,gr.max()+0.1)
# Out:
# (0, 1.7100000000000002)

# %%
log(high_prots).corr()
# Out:
#                   chemostat µ=0.12  galactose  chemostat µ=0.20   acetate  \chemostat µ=0.12          1.000000   0.954443          0.973775  0.955398   galactose                 0.954443   1.000000          0.953157  0.986289   chemostat µ=0.20          0.973775   0.953157          1.000000  0.952044   acetate                   0.955398   0.986289          0.952044  1.000000   chemostat µ=0.35          0.971646   0.957623          0.982401  0.961441   glucosamine               0.912331   0.965498          0.920052  0.966460   pyruvate                  0.936853   0.971037          0.947194  0.975342   glycerol                  0.909328   0.968976          0.910541  0.962784   fumarate                  0.908149   0.968435          0.918730  0.968590   succinate                 0.919906   0.971943          0.927147  0.974216   chemostat µ=0.5           0.957952   0.976630          0.957884  0.982024   anaerobic                 0.950684   0.954049          0.950817  0.956801   glucose                   0.885886   0.946453          0.885626  0.942802   LB                        0.877832   0.900571          0.877060  0.907227                     chemostat µ=0.35  glucosamine  pyruvate  glycerol  fumarate  \chemostat µ=0.12          0.971646     0.912331  0.936853  0.909328  0.908149   galactose                 0.957623     0.965498  0.971037  0.968976  0.968435   chemostat µ=0.20          0.982401     0.920052  0.947194  0.910541  0.918730   acetate                   0.961441     0.966460  0.975342  0.962784  0.968590   chemostat µ=0.35          1.000000     0.937393  0.960101  0.928162  0.933729   glucosamine               0.937393     1.000000  0.974691  0.972798  0.978814   pyruvate                  0.960101     0.974691  1.000000  0.964572  0.971213   glycerol                  0.928162     0.972798  0.964572  1.000000  0.983774   fumarate                  0.933729     0.978814  0.971213  0.983774  1.000000   succinate                 0.945137     0.976602  0.979072  0.981301  0.990989   chemostat µ=0.5           0.971654     0.963064  0.975418  0.961622  0.965238   anaerobic                 0.964976     0.946977  0.952084  0.932388  0.936637   glucose                   0.910308     0.982306  0.949308  0.968735  0.967191   LB                        0.889195     0.931202  0.908728  0.919253  0.921884                     succinate  chemostat µ=0.5  anaerobic   glucose        LB  chemostat µ=0.12   0.919906         0.957952   0.950684  0.885886  0.877832  galactose          0.971943         0.976630   0.954049  0.946453  0.900571  chemostat µ=0.20   0.927147         0.957884   0.950817  0.885626  0.877060  acetate            0.974216         0.982024   0.956801  0.942802  0.907227  chemostat µ=0.35   0.945137         0.971654   0.964976  0.910308  0.889195  glucosamine        0.976602         0.963064   0.946977  0.982306  0.931202  pyruvate           0.979072         0.975418   0.952084  0.949308  0.908728  glycerol           0.981301         0.961622   0.932388  0.968735  0.919253  fumarate           0.990989         0.965238   0.936637  0.967191  0.921884  succinate          1.000000         0.979331   0.944864  0.964805  0.915399  chemostat µ=0.5    0.979331         1.000000   0.973030  0.948227  0.904350  anaerobic          0.944864         0.973030   1.000000  0.939215  0.877735  glucose            0.964805         0.948227   0.939215  1.000000  0.917144  LB                 0.915399         0.904350   0.877735  0.917144  1.000000

# %%
glob = high_prots.sum()covs = []grcovs = []for index, row in high_prots.iterrows():    covs.append(row.corr(glob))    grcovs.append(row.corr(gr))density = gaussian_kde(covs)#plot(xs,density(xs))density = gaussian_kde(grcovs)#plot(xs,density(xs))hist([covs,grcovs])title('Correlation of proteins with GR vs. with global cluster')

# %%
plot(covs,grcovs,'.')plot(covs,covs)xlim(0,1)ylim(0,1)
# Out:
# (0, 1)

# %%
high_cor_prots = {}for row_index, row in high_prots.iterrows():    desc = []    eco = ecoli_data['UP_AC'][row_index]    uniprot = unidict[eco]    if uniprot in annot_dict:	desc = annot_dict[uniprot]	for i in range(0,3):	    if desc[i] not in high_cor_prots:	       high_cor_prots[desc[i]]=0	    high_cor_prots[desc[i]]+=1for i in set([x[1] for x in annot_dict.values()]):    if i in prots:	if i in high_cor_prots:	    print "%s : %d / %d" % (i,high_cor_prots[i],prots[i])	else:	    print "%s : %d / %d" % (i,0,prots[i])

# %%
ecoli_data_values.min()*2500 / ecoli_data_values.sum()
# Out:
# chemostat µ=0.12    1.708895e-06galactose           1.009170e-05chemostat µ=0.20    8.900863e-06acetate             1.121313e-05chemostat µ=0.35    5.418625e-08glucosamine         4.743409e-05pyruvate            2.265485e-05glycerol            2.536421e-05fumarate            1.797785e-06succinate           4.133119e-07chemostat µ=0.5     6.909304e-06anaerobic           6.540593e-07glucose             1.406850e-04LB                  5.537180e-06dtype: float64

# %%
ecoli_data_values.sum()
# Out:
# chemostat µ=0.12    0.999950galactose           0.999936chemostat µ=0.20    0.999948acetate             0.999920chemostat µ=0.35    0.999861glucosamine         0.999860pyruvate            0.999908glycerol            0.999859fumarate            0.999833succinate           0.999905chemostat µ=0.5     0.999893anaerobic           0.999825glucose             0.999819LB                  0.999833dtype: float64

# %%
#Initialization of basic data containers, gene annotation data, growth rates and cell volumes and selection of conditions to analyze.import csvfrom pandas.io.parsers import read_csvimport pandas as pdfrom scipy.stats import gaussian_kde,linregresspylab.rcParams['figure.figsize']=(8.0,6.0)#load uniprot to eco gene id mapping and convert it to a dictionary:unidict = {}uni_to_eco = read_csv('eco_uniprot_mapping.csv',sep='[\t:]',encoding='iso-8859-1',header = None, names = ['eco','bla','uniprot'])for i,row in uni_to_eco.iterrows():     unidict[row['uniprot']]=row['eco']    #load the eco annotation tree:annot_dict = {}with open('hierarchy_standardised.tms','rb') as annot_file:     annots = csv.reader(annot_file,delimiter='\t') #,encoding='iso-8859-1')     for row in annots:     	 if len(row) == 2:	    cat = row [-1]	 elif len(row) == 3:	    subcat = row[-1]	 elif len(row) == 4:	    component = row[-1]	 elif len(row) == 5:	    annot_dict[row[-1]]=(cat,subcat,component)	      # define the growth rates:gr = {    u'chemostat \u00b5=0.12': 0.12,     u'galactose':0.17,     u'chemostat \u00b5=0.20':0.2,     u'acetate':0.29,     u'chemostat \u00b5=0.35':0.35,    u'glucosamine':0.39,     u'pyruvate':0.4,     u'glycerol':0.47,    u'fumarate':0.47,     u'succinate':0.49,     u'chemostat \u00b5=0.5':0.5,     u'anaerobic' : 0.55,     u'glucose': 0.6#     u'LB':1.61,    }gr = pd.Series(gr)# define cell volumes:volumes = {u'glucose': 3.2, u'anaerobic' : 2.9, u'chemostat \u00b5=0.12': 2.1, u'chemostat \u00b5=0.5':2.6, u'galactose':1.9, u'acetate':2.4, u'glycerol':2.3,#     u'LB':4.4,     u'glucosamine':2.9, u'fumarate':2.4, u'succinate':2.4, u'pyruvate':2.1, u'chemostat \u00b5=0.20':2.2, u'chemostat \u00b5=0.35':2.4}volumes = pd.Series(volumes)# first load the data from the file.# As the file was exported from Excel, it uses Excel's encoding.ecoli_data = read_csv('coli_data.csv',header=1,encoding='iso-8859-1')#Split the data loaded into two sets - weight and count.idx = ecoli_data.columnsecoli_data_weight = ecoli_data[idx[0:10].append(idx[29:])]ecoli_data_count = ecoli_data[idx[0:29]]# Define the list of conditions that will be relevant for the analysis, (and the description column):cond_list = [    u'chemostat \u00b5=0.12',    u'galactose',    u'chemostat \u00b5=0.20',    u'acetate',    u'chemostat \u00b5=0.35',    u'glucosamine',    u'pyruvate',    u'glycerol',    u'fumarate',    u'succinate',    u'chemostat \u00b5=0.5',    u'anaerobic',    u'glucose']#Define the text fields that will be relevant for the analysis:desc_list = ['Description','UP_AC']# Refine the DataFrames to include only these conditions (and the protein descriptions):count_cond = desc_list+cond_listecoli_data_count = ecoli_data_count[count_cond]#duplicate headers are modified by read_csv and include a trailing '.1' string in their name.weight_cond = desc_list+[x+'.1' for x in cond_list] ecoli_data_weight = ecoli_data_weight[weight_cond]#rename the columns to remove the trailing '.1'ecoli_data_weight.columns = count_condecoli_data_weight = ecoli_data_weight[ecoli_data_weight != 'below LOQ']ecoli_data_weight[cond_list] = ecoli_data_weight[cond_list].astype('float')ecoli_data_weight[desc_list] = ecoli_data_weight[desc_list].astype('string')#select the relevant data for analysis out of the two options:ecoli_data = ecoli_data_count#convert all columns, excluding 'Description', to floats, and 'Description' to string.ecoli_data = ecoli_data[ecoli_data != 'below LOQ']ecoli_data[cond_list] = ecoli_data[cond_list].astype('float')ecoli_data[desc_list] = ecoli_data[desc_list].astype('string')#Normalize to get concentrations (Use the total protein weight as the normalizing factor to avoid errors in cell volume measurements)ecoli_data[cond_list] = ecoli_data[cond_list] / ecoli_data_weight[cond_list].sum() #volumes[cond_list]#get the ribosomal proteins.ecoli_data_values = ecoli_data.drop(desc_list,1)ecoli_data_values = ecoli_data_values.dropna()ribs = ecoli_data['Description'].map(lambda x: 'ribosomal protein' in x)ribs_data = ecoli_data_values[ribs]ribs_avg = ribs_data.sum()gr = gr[ribs_avg.index]volumes = volumes[ribs_avg.index]
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.py:1943: UserWarning: Boolean Series key will be reindexed to match DataFrame index.  "DataFrame index.", UserWarning)

# %%
########################### Analysis of correlation of proteins to growth rate.xs = linspace(-1,1,100)covs = []catcovs = {}prots = {}high_cor_prots = {}threshold = 0.3hc_indices = []hc_prots = pd.DataFrame(columns = ecoli_data_values.columns)for row_index, row in ecoli_data_values.iterrows():    desc = []    # calculate the correlation and add it to the statistics    cov = row.cov(gr)/(row.std() * gr.std())    covs.append(cov)    # get the protein annotation information    eco = ecoli_data['UP_AC'][row_index]    uniprot = unidict[eco]    if uniprot in annot_dict:	desc = annot_dict[uniprot]	# set the counters of all the annotation fields that this protein belong to.	for i in range(0,3):	    if desc[i] not in prots:	       prots[desc[i]]=0	       high_cor_prots[desc[i]]=0	       catcovs[desc[i]]=[]	    prots[desc[i]]+=1	    catcovs[desc[i]].append(cov)	    if cov > threshold: # threshold for gr correlated protein		high_cor_prots[desc[i]]+=1    if cov > 0.5:# and cov < 0.8:       hc_indices.append(row_index)       hc_prots = hc_prots.append(row)prots_num = len(covs)density = gaussian_kde(covs)plot(xs,density(xs),label='All proteins')title('Estimated distributions of correlation with growth rate by functional group')print "number of proteins compared: %d" % prots_numprint "correlation by categories:"for i in set([x[0] for x in annot_dict.values()]):    if i in prots:	if i in high_cor_prots:	    print "%s : %d / %d" % (i,high_cor_prots[i],prots[i])	else:	    print "%s : %d / %d" % (i,0,prots[i])groups = ['Translation', 'Folding, Sorting and Degradation', 'Lipid Metabolism', 'Energy Metabolism', 'Membrane Transport', 'Amino Acid Metabolism', 'Not mapped']print "correlation by sub-categories:"for i in set([x[1] for x in annot_dict.values()]):    if i in prots:        if i in groups:	    density = gaussian_kde(catcovs[i])	    plot(xs,density(xs)*(float(prots[i])/prots_num),label=i)	if i in high_cor_prots:	    print "%s : %d / %d" % (i,high_cor_prots[i],prots[i])	else:	    print "%s : %d / %d" % (i,0,prots[i])legend(loc='upper left')savefig('some_subcategories_distributions.png')
# Out:
# number of proteins compared: 1981correlation by categories:Environmental Information Processing : 8 / 26Genetic Information Processing : 191 / 289Cellular Processes : 4 / 16Not mapped : 330 / 990Metabolism : 369 / 657correlation by sub-categories:Nucleotide Metabolism : 48 / 70Transcription : 21 / 44Metabolism of Other Amino Acids : 16 / 24Membrane Transport : 23 / 80Not mapped : 330 / 990Cell Motility : 0 / 5Other enzymes : 64 / 124Glycan Biosynthesis and Metabolism : 8 / 14Energy Metabolism : 25 / 37Signal Transduction : 8 / 26Metabolism of Cofactors and Vitamins : 45 / 65Cell Growth and Death : 1 / 3Translation : 89 / 109Lipid Metabolism : 10 / 34DNA maintenance : 30 / 49Xenobiotics Biodegradation and Metabolism : 2 / 4Metabolism of Terpenoids and Polyketides : 12 / 16Vesicular transport : 0 / 3Amino Acid Metabolism : 86 / 113Folding, Sorting and Degradation : 51 / 87Cytoskeleton : 3 / 5Carbohydrate Metabolism : 62 / 138

# %%
hist(covs,20)
# Out:
# (array([ 33,  64,  70,  51,  65,  51,  73,  62,  71,  86,  97, 120, 123,       134, 159, 160, 199, 184, 121,  58]), array([-0.94917341, -0.85514047, -0.76110753, -0.6670746 , -0.57304166,       -0.47900872, -0.38497579, -0.29094285, -0.19690991, -0.10287698,       -0.00884404,  0.0851889 ,  0.17922183,  0.27325477,  0.3672877 ,        0.46132064,  0.55535358,  0.64938651,  0.74341945,  0.83745239,        0.93148532]), <a list of 20 Patch objects>)

# %%
# plot the correlation of growth rate to the sum of ribosomal proteinsplot(gr.values,ribs_avg.values,'.')

# %%
covs = []catcovs = {}prots = {}high_cor_prots = {}threshold = 0.3maxval = 5j = 0values = []group = 'Energy Metabolism'for row_index, row in ecoli_data_values.iterrows():    desc = []    # calculate the correlation    cov = row.cov(gr)/(row.std() * gr.std())    # get the protein annotation information    eco = ecoli_data['UP_AC'][row_index]    uniprot = unidict[eco]    if uniprot in annot_dict:	desc = annot_dict[uniprot]	if desc[1] == group and j < maxval:	    j += 1	    normvals = row/row.sum()	    values.append(normvals)	    covs.append(cov)for i in range(0,len(values)):    plot(gr.values,values[i],'-o',label="%f" % covs[i])legend(loc='upper left')title('five random %s proteins. Legend shows covariance' % group)ylim([0,0.2])xlim([0,0.65])savefig('Five%sProts.png' % group)

# %%
hc_weights = hc_prots / hc_prots.sum()

# %%
norm_vars = hc_weights.std(axis=1) / hc_weights.mean(axis=1)plot(hc_weights.mean(axis=1),norm_vars,'.')xscale('log')title('CV of intrinsic strength decreases when measured values are higher')xlabel('Intrinsic strength (log)')ylabel('CV of intrinsic strength')savefig('CVvsDetectionLevel.png')

# %%
high_weights = hc_weights[hc_weights.mean(axis=1)>0.0001]high_prots = hc_prots[hc_weights.mean(axis=1)>0.0001]norm_vars = high_weights.std(axis=1) / high_weights.mean(axis=1)#plot(high_weights.mean(axis=1),norm_vars,'.')#xscale('log')

# %%
plot(high_prots.std(axis=1)/high_prots.mean(axis=1),norm_vars,'.')plot(high_prots.std(axis=1)/high_prots.mean(axis=1),high_prots.std(axis=1)/high_prots.mean(axis=1),label='y=x')plot(high_prots.std(axis=1)/high_prots.mean(axis=1),high_prots.std(axis=1)/high_prots.mean(axis=1)-0.183,label='y=x-CV(cluster)')title('Intrinsic strengths predict measured values')xlabel('CV of protein concentration across conditions')ylabel('CV of intrinsic strength across conditions')xlim(0,1.3)ylim(0,1.3)legend()savefig('IntStrengthCVvsRawCV.png')

# %%
print gr.std()/gr.mean()print high_prots.sum().std()/high_prots.sum().mean()
# Out:
# 0.3923926604820.1831168363

# %%
plot(gr,high_prots.sum(),'.')plot(gr,gr/40000)xlim(0,0.65)ylim(0,0.000015)
# Out:
# (0, 1.5e-05)

# %%
log(high_prots).corr()
# Out:
#                   chemostat µ=0.12  galactose  chemostat µ=0.20   acetate  \chemostat µ=0.12          1.000000   0.961797          0.980463  0.965131   galactose                 0.961797   1.000000          0.965490  0.986237   chemostat µ=0.20          0.980463   0.965490          1.000000  0.964753   acetate                   0.965131   0.986237          0.964753  1.000000   chemostat µ=0.35          0.974452   0.959071          0.984779  0.967218   glucosamine               0.930812   0.973148          0.938985  0.967426   pyruvate                  0.948969   0.973446          0.957386  0.976492   glycerol                  0.934571   0.976617          0.936108  0.971049   fumarate                  0.936309   0.975958          0.942488  0.975816   succinate                 0.944193   0.977201          0.948074  0.979668   chemostat µ=0.5           0.968016   0.980976          0.972097  0.984127   anaerobic                 0.962908   0.963570          0.964048  0.965467   glucose   
# ...
